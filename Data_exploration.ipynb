# %%
import pandas as pd

# %%
df = pd.read_csv('Data/TB_Burden_Country.csv')

# %%
df['Estimated HIV in incident TB (percent)'].head()
# Out:
# 0    0.06
# 1    0.07
# 2    0.08
# 3    0.10
# 4    0.11
# Name: Estimated HIV in incident TB (percent), dtype: float64

# %%
df_means_prevalence = df[['Country or territory name','Estimated prevalence of TB (all forms) per 100 000 population']].groupby('Country or territory name').mean()

# %%
df_means_prevalence['Estimated prevalence of TB (all forms) per 100 000 population'].max()
# Out:
# 1360.4166666666667

# %%
df.describe()
# Out:
#        ISO numeric country/territory code         Year  \
# count                         5120.000000  5120.000000
# mean                           433.576563  2001.549023
# std                            255.116018     6.933272
# min                              4.000000  1990.000000
# 25%                            212.000000  1996.000000
# 50%                            430.000000  2002.000000
# 75%                            646.000000  2008.000000
# max                            894.000000  2013.000000
#
#        Estimated total population number  \
# count                       5.120000e+03
# mean                        2.915671e+07
# std                         1.183725e+08
# min                         1.129000e+03
# 25%                         5.601190e+05
# 50%                         5.172118e+06
# 75%                         1.752404e+07
# max                         1.385567e+09
#
#        Estimated prevalence of TB (all forms) per 100 000 population  \
# ...

# %% [markdown]
# #### Note on columns:
# Since the data is composed of estimates, there are high and low bound vlaues provided for each value estimated. These bounds may be useful to some analysis, but I will be ignoring them primarily in mine. This leaves the primary metrics as the 'per 100 000' values of prevalence, incidence, and mortality. As well as the 'HIV+' vs 'all other cases' breakdowns of mortality and incidence values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5120 entries, 0 to 5119
# Data columns (total 47 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Country or territory name                                                                       5120 non-null   object
#  1   ISO 2-character country/territory code                                                          5096 non-null   object
#  2   ISO 3-character country/territory code                                                          5120 non-null   object
#  3   ISO numeric country/territory code                                                              5120 non-null   int64
#  4   Region                                                                                          5120 non-null   object
# ...

# %% [markdown]
# #### Note on nulls:
# Many columns contain many nulls, so care will have to be taken to properly filter nulls when using aggregate values (as is often the case) to create visualizations in Tableau.
